# %% [markdown]
# # ⚽ Mission 4 — Building the AI Coach's Toolbox
#
#
# Your AI Coach can now:
# - ✅ Read player data
# - ✅ Make decisions
# - ✅ Simulate a football match
#
# A smart coach does not only make decisions during a match. A great coach remembers what happened, studies past performances, and learns how players improve over time.
#
# But there is one major problem... Every time the AI Coach wants to calculate a metric, you have to rewrite the exact same lines of code.
#
# Professional software engineers don't copy and paste code everywhere. They build **reusable tools**. Today, you will build the AI Coach's personal toolbox! You are going to stop writing simple scripts and start structuring real software modules.
#
# ### Difficulty:
# Beginner
#
# ### Duration:
# 3 Hours
#
# ### Skills Needed:
# - ✓ Create variables
# - ✓ Use lists and dictionaries
# - ✓ Make decisions with if statements
# - ✓ Use loops to repeat actions
# - ✓ Simulate soccer events
#
# ### Skills Unlocked Today:
#
# - ✓ Organizing match history with data structures
# - ✓ Creating reusable functions
# - ✓ Calculating player performance scores
# - ✓ Updating player statistics after games
# - ✓ Comparing past and present performance
# - ✓ Building a simple AI Coach memory system
#
#
# ### 🚀 Mission Challenge:
#
# At the end of today's mission, your AI Coach will be able to answer questions like:
#
# - "Who is the most improved player?"
# - "Which skill should this player train next?"
# - "Did our team become better after training?"
# - "How did our last three matches compare?"
#
# You are no longer just programming a soccer simulator. You are beginning to build an AI assistant that can remember, analyze, and improve.

# %% [markdown]
# ## 🧠 Learning Objectives
# By the end of this mission, you will be able to:
# 1. Write reusable code blocks using **Functions**.
# 2. Pass real player information into those functions (**Parameters**).
# 3. Send calculated metrics back to your main app (**Return Values**).
# 4. Build a comprehensive soccer statistics library.
# 5. Separate player data cleanly from logic.

# %% [markdown]
# ## 🧠 Mission03 Review
#
# Here are some practice exercises that encourage using multiple conditions with if, elif, else, and logical operators (and, or).

# %%
messi_goat = True

if messi_goat:
    print("Messi is the GOAT!")
else:
    print("Lies.")
# Out:
# Messi is the GOAT!

# %%
ms_aliabadi_akhmoo = True

if ms_aliabadi_akhmoo:
    print("Khonum Aliabadi is very akhmoo")
else:
    print("Khonume maryam is normal")
# Out:
# Khonum Aliabadi is very akhmoo

# %%
grade = 87

if grade >= 90:
    print("A")
elif grade >= 80:
    print("B")
elif grade >= 70:
    print("C")
elif grade >= 60:
    print("D")
else:
    print("F")
# Out:
# B

# %%
goals = 56

if goals >= 50:
    print("world class striker")

elif goals >= 40:
    print("great striker")

elif goals >= 30:
    print("class striker")

elif goals >= 20:
    print("proper striker")

else:
    print("meh striker")
# Out:
# world class striker

# %% [markdown]
# ## 🧠 Pre-Match Warm-Up
#
# Before we build the AI Coach's Toolbox, let's run through a quick warm-up to make sure our core skills are sharp. In the previous three missions, your AI learned how to store data, look at stats, make decisions, and track game time.

# %%
name = "Alex",
position = "Midfielder"
goals = 3
assists = 3
defending = 65
shooting = 87
speed = 95
passing = 78

# %% [markdown]
# Let's test these skills in one single tactical drill!

# %% [markdown]
# ### The Drill: Player Performance Drill
#
# Below is a dictionary containing a single player's game stats. Complete the code cells below to calculate their impact and determine if they earn a "Match MVP" or "Training Stars" badge.
#
# Run this cell first to set up the data:

# %%
# Mission 1 Review: Storing data in a dictionary
player_stats = {
    "name": "Alex",
    "position": "Striker",
    "goals": 3,
    "assists": 3,
    "defending": 65,
    "shooting" : 87,
    "speed" : 95,
    "passing" : 78
}

print(f"Data loaded for {player_stats['name']}!")
# Out:
# Data loaded for Alex!

# %% [markdown]
# ### 🧩 Challenge 1: Stat Analysis (Missions 1 - 2)
#
# Goal: Access the data, calculate the total contributions (Total Goals + Total Assists), and overall rating of the player.

# %% [markdown]
#  Calculate total goal contributions (Goals + Assists)

# %%
total_contribution = (goals + assists)

print(total_contribution)
# Out:
# 6

# %% [markdown]
# Calculate the player's overall rating.
#
# Hint: (speed + passing + shooting + defending) / 4

# %%
# Your code here..



#overall_rating = (speed + passing + shooting + defending) / 4
overall_rating = (player_stats["speed"] + player_stats["passing"] + player_stats["shooting"] + player_stats["defending"]) / 4
print(overall_rating)
# Out:
# 81.25

# %% [markdown]
# Print total contribution and overal rating of the player.

# %%
# Your code here..

print(f"The overall rating is {overall_rating}.")
print(f"The total contribution is {total_contribution}.")
# Out:
# The overall rating is 81.25.
# The total contribution is 6.

# %%
# Assume these are the stats over 4 games
minutes_played = [80, 75, 90, 75]
goals = [1,0,2,1]
assists = [1,1,0,0]

# %% [markdown]
# We can calculate the total minutes Alex played over 4 games using for loops.

# %%
total_minutes = 0
for mins in minutes_played:
    total_minutes += mins

print("Total minutes played:", total_minutes)
# Out:
# Total minutes played: 320

# %% [markdown]
# Calculate total goals over 4 games.

# %%
goals = [1,0,2,1]
total_goals = 0
for goal in goals:
    total_goals += goal

print(f"Total goals scored is {total_goals} goals.")
# Out:
# Total goals scored is 4 goals.

# %% [markdown]
# Calculate total assists over 4 games.

# %%
total_assists = 0
for assist in assists:
  total_assists += assist

print(f"Total assists given is {total_assists} assists.")
# Out:
# Total assists given is 2 assists.

# %% [markdown]
# ### 🧩 Challenge 2: The Tactical Decision (Mission 3)
# Goal: Use conditional statements (if-elif-else) to evaluate the player's performance badge based on their contributions.
#
# - MVP Badge: If total_contributions is 5 or more.
# - Impact Player Badge: If total_contributions is between 2 and 4.
# - Hard Worker Badge: Anything else.

# %% [markdown]
# Print the result badge in this format. For example :
#
# Review Complete! Alex has earned the MVP Badge!

# %%
# Your code here..

#mvp = 5
#impact_player = 2 <= 4
#hard_worker =< 1

total_goal_contributions = total_goals + total_assists

if total_goal_contributions >= 5:
    print("MVP Badge.")

elif 2 < total_goal_contributions < 4:
    print("Impact Pler Badge.")

else:
    print("Hard Worker Badge.")
# Out:
# MVP Badge.

# %% [markdown]
# Notice how much code we had to write just to analyze one player? If we had a squad of 11 players, copying and pasting this code would become messy very quickly.
#
# In Mission 4, we are going to wrap logic exactly like this into reusable functions (tools) so our AI Coach can evaluate an entire stadium of players instantly!

# %% [markdown]
# ## 🟩 Part 1 — Why Functions Exist
# Without functions, if you want to find a player's performance contribution across 20 different players, you would have to manually type or copy-paste code like this:
# ```python
# print(player["goals"] + player["assists"])
# ```
#
# With functions, we use the `def` keyword (short for *define*) to create a machine template once, and reuse it anywhere!

# %%
# Mission 1 Review: Storing data in a dictionary
player_stats = {
    "name": "Alex",
    "position": "Striker",
    "goals": 3,
    "assists": 3,
    "defending": 65,
    "shooting" : 87,
    "speed" : 95,
    "passing" : 78
}

# %%
# Defining our very first soccer tool template
def total_contribution(goals, assists):
    return goals + assists

# Testing the tool
messi_contribution = total_contribution(12, 6)

print("Messi Total Contribution:", messi_contribution)
# Out:
# Messi Total Contribution: 18

# %% [markdown]
# ## 🟩 Part 2 — Parameters and Arguments
# Parameters act like specialized temporary storage buckets inside a function that wait to receive input information from the outside world. Look at how a dictionary variable representing a player can be cleanly passed as a parameter object.

# %%
# A real dictionary representing our player data row
player_1 = {
    "name": "Isaac",
    "position": "Forward",
    "goals": 12,
    "assists": 6
}

def total_contribution_dict(player):
    # The 'player' parameter acts as a doorway for our dictionary
    return player["goals"] + player["assists"]

# Passing the whole player into the tool
result = total_contribution_dict(player_1)
print(f"{player_1['name']} total output value:", result)
# Out:
# Isaac total output value: 18

# %% [markdown]
# ## 🟩 Part 3 — Return Values vs. Printing
# There is a huge distinction between `print()` and `return`:
# - `print()` simply splashes text out onto the screen for human eyes. The computer immediately forgets it.
# - `return` passes the calculated value **back into the computer's memory bank**, allowing you to save it into variables to use in calculations later!

# %%
def get_rating_value():
    return 85

# Because it uses 'return', we can save it and do math on it later!
saved_rating = get_rating_value()
boosted_rating = saved_rating + 5
print("Boosted Rating Memory State:", boosted_rating)
# Out:
# Boosted Rating Memory State: 90

# %% [markdown]
# ## 🟩 Part 4 — Building the Soccer Toolbox
# Let's practice writing individual modular tools that accept a standard player dictionary object. Run the setup cell below to initialize our sample athlete data profile.

# %%
player1 = {
    "name": "Artin",
    "position": "Forward",
    "goals": 19,
    "assists": 16,
    "speed": 92,
    "passing": 100
}

# %%
player2 = {
    "name": "Jeff",
    "position": "Defend",
    "goals": 9,
    "assists": 16,
    "speed": 72,
    "passing": 10
}

# %% [markdown]
# ### 🎯 Tool Construction Lab
# Complete the empty function blocks below using the matching requirements.

# %%
# 1. Calculate an overall rating score using an average of speed and passing parameters
def overall_rating(player):
    # Write your logic here and replace 'None' with your return calculation
    return (player["speed"] + player["passing"]) / 2


result= overall_rating (player2)

print(result)
# Out:
# 41.0

# %%
# 2. Check if a player is a forward. Return True if position is equal to "Forward", else False
def is_forward(player):
    # Write your logic here
    if player ["position"] == "Forward":
        return True

    else:
        return False

output= is_forward(player2)
print(output)
# Out:
# False

# %% [markdown]
# ### 📊 Complex Output Formatting
# We can use functions to print beautifully structured dashboards and reports seamlessly without typing messy print layouts multiple times.

# %%
def coach_report(player):
    print("====================")
    print("   PLAYER REPORT    ")
    print(f"Name: {player['name']}")
    print(f"Position: {player['position']}")
    print(f"Goals: {player['goals']}")
    print(f"Assists: {player['assists']}")
    print("====================")

# Call your coach report function
coach_report(player1)
coach_report(player2)
# Out:
# ...
#    PLAYER REPORT
# Name: Artin
# Position: Forward
# Goals: 19
# Assists: 16
# ...
#    PLAYER REPORT
# Name: Jeff
# Position: Defend
# Goals: 9
# Assists: 16
# ...

# %% [markdown]
# ## 🟩 Part 5 — Mini Functional Challenges
# Now it's your turn to design complete algorithmic software tools from scratch!

# %% [markdown]
# ### 🥉 Bronze Challenge:
# Write a function named `goal_difference(goals_for, goals_against)` that calculates and returns the absolute net variance between goals scored vs. goals conceded.

# %%
# Write your Bronze Challenge here
def goal_difference(goals_for, goals_against):
    return abs(goals_for - goals_against)

# %%
goals_for = 16
goals_against = 0

output = goal_difference(goals_for, goals_against)
print(output)
# Out:
# 16

# %% [markdown]
# ### 🥈 Silver Challenge:
# Write a function named `match_result(home_score, away_score)` that returns string statements (`"Win"`, `"Loss"`, or `"Draw"`) relative to the perspective of the home squad.

# %%
# Write your Silver Challenge here
def match_result(home_score, away_score):

    if home_score > away_score:
        print("Win")

    elif home_score < away_score:
        print("Loss")

    else:
        print("Draw")

# %%
home_score = 4
away_score = 3

match_result(home_score, away_score)
# Out:
# Win

# %% [markdown]
# ### 🥇 Gold Challenge:
# Write a complex evaluation function named `choose_best_striker(player1, player2)` that accepts two distinct player dictionary blocks, compares their raw goals counts, and returns the whole dictionary row of whichever player has scored more goals.

# %%
# Write your function below and test it using striker_a and striker_b

def choose_best_striker(player1, player2):
    if player1["goals"] > player2["goals"]:
        print(f"{player1["name"]} scored more goals.")

    elif player2["goals"] > player1["goals"]:
        print(f"{player2["name"]} scored more goals.")

    else:
        print("Same amount of goals.")


# Test Data Setup for Gold Challenge
striker_a = {"name": "Kane", "goals": 12}
striker_b = {"name": "Haaland", "goals": 12}

choose_best_striker(player1, player2)
# Out:
# Artin scored more goals.

# %% [markdown]
# ## 🟩 Part 6 — AI Engineering Corner
# Large scale Artificial Intelligence agents and complex engine environments aren't written as single monolithic scripts. They are built using thousands of small, specialized functions working cleanly together. Each minor tool does exactly one specific job flawlessly. By mastering functions today, you are structuring code just like data engineering professionals do.

# %% [markdown]
# ### 📚 What is a Code Library?
# Up until now, you have been building individual tools (functions) one by one. But as your software grows, keeping all your tools loose in your workspace makes things messy.
#
# In programming, a Library is a collection of reusable code (like functions, variables, or classes) that are organized together into a single package.
#
# The Toolbox Analogy: Think of individual functions as tools—a hammer, a screwdriver, or a wrench. A Library is the actual heavy-duty toolbox where you organize and store all those tools so you can carry them to any soccer stadium or project easily without losing them.
#
# 💡 A Simple Example of a Library
# In Python, you can group functions together into a .py file (called a module) and then bring them into your main notebook using the import command.
#
# Imagine we have a mini-library file called soccer_math.py:

# %%
# Content inside soccer_math.py
def calculate_points(wins, draws):
    return (wins * 3) + (draws * 1)

# %%
wins = 9
draws = 2

calculate_points(wins, draws)
# Out:
# 29

# %% [markdown]
# To use this library in our main project, we simply import it like this:

# %%
#import soccer_math

# Using our library tool
#team_points = soccer_math.calculate_points(wins=5, draws=2)
#print(f"Total Team Points: {team_points}")

# %% [markdown]
# ## 🟩 Part 7 — Final Mission Challenge ⭐⭐⭐
# It’s time to take everything you've engineered so far. Assemble all of your newly engineered tools into a complete, integrated software asset: the **Soccer Analytics Library**.
#
# ### 🛠️ Final Deliverable Checklist:
# Your mission workspace code cell below must contain working definitions for:
# - [ ] `total_contribution(player)`
# - [ ] `overall_rating(player)`
# - [ ] `match_result(home, away)`
# - [ ] `goal_difference(goals_for, goals_against)`
# - [ ] `coach_report(player)` including a formatted display containing all player metrics computed cleanly by your library functions.

# %%
# Write your comprehensive Soccer Analytics Library code blueprint here!
