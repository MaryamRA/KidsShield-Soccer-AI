# %% [markdown]
# # ⚽ Mission 02: Explore Your Soccer Team Dataset
#
#
# ### Welcome back,
#
# Yesterday you built the first version of a Soccer Dataset. You learned how to store information about soccer players using variables, lists, and dictionaries.Today, your mission is different. The AI Coach now has a dataset full of player information, but it doesn't know how to find, read, or understand that information. Your job is to teach the AI Coach how to explore its dataset.
#
# By the end of today's mission, you will have:
#
# - Created a complete soccer team dataset
# - Explored a complete soccer team dataset.
# - Retrieved information from dictionaries and lists.
# - Added new player attributes such as speed, stamina, and shooting.
# - Updated player statistics after a match.
# - Built your first helper functions to analyze players.
# - Generated your first AI player report.
#
# ### Difficulty:
# Beginner
#
# ### Duration:
# 3 Hours
#
# ### Skills Needed:
# None

# %% [markdown]
# ## 🎯 Learning Objectives
# - Access values in dictionaries
# - Access players in a list of dictionaries
# - Update player information
# - Add new player features
# - Perform arithmetic on player statistics
# - Write your first python functions

# %% [markdown]
# ## Part 1 – Review Mission 01

# %%
messi = {
    "name": "Messi",
    "goals": 20,
    "assists": 18
}

print(messi)
# Out:
# {'name': 'Messi', 'goals': 20, 'assists': 18}

# %%
#Accessing dictionary data
print(messi["name"])
# Out:
# Messi

# %%
print(messi["assists"])
# Out:
# 18

# %%
players = [
    {"name": "Messi", "position":"forward",  "goals": 21, "assists": 18},
    {"name": "Haaland", "position":"forward", "goals": 35, "assists": 5},
    {"name": "Saka", "position":"forward", "goals": 12, "assists": 13}
]

# %%
print(f"{players[1]["name"]} plays in {players[1]["position"]} position.")
# Out:
# Haaland plays in forward position.

# %%
#Accessing list data
print(players[0])
# Out:
# {'name': 'Messi', 'position': 'forward', 'goals': 21, 'assists': 18}

# %%
#Accessing dataset data
print(players[0]["name"])
# Out:
# Messi

# %%
#Accessing dataset data
print(players[2]["goals"])
# Out:
# 12

# %% [markdown]
# ### Exercise
# Print the following:
# Messi scored 30 goals.

# %%
#print(f"{players[0]}["name"] scored [goals"] goals.")

#print(players[0]["name"])

#print(players[1]["position"])

#print(players[2]["assists"])

#print(f{players}[2]["name"]"had"["assists"]"assists.")

#print(f"{players[2]["name"]} is a great player")

#print(f"{players[2]["name"]} had {players[2]["assists"]} assists.")

print(f"{players[0]["name"]} scored 30 goals.")
# Out:
# Messi scored 30 goals.

# %%
Add another player like Ronaldo to dataset.

# %%
ronaldo = {
    "name": "Ronaldo",
    "position": "Forward",
    "goals": 25,
    "assists": 8
}

# %%
# TODO

players = [
     {"name": "Messi", "position":"forward",  "goals": 21, "assists": 18},
    {"name": "Haaland", "position":"forward", "goals": 35, "assists": 5},
    {"name": "Saka", "position":"forward", "goals": 12, "assists": 13},
     {"name": "Ronaldo", "position": "Forward", "goals": 25, "assists": 8}

]

print(players)
# Out:
# [{'name': 'Messi', 'position': 'forward', 'goals': 21, 'assists': 18}, {'name': 'Haaland', 'position': 'forward', 'goals': 35, 'assists': 5}, {'name': 'Saka', 'position': 'forward', 'goals': 12, 'assists': 13}, {'name': 'Ronaldo', 'position': 'Forward', 'goals': 25, 'assists': 8}]

# %% [markdown]
# ## Part 2 — Build Your Team Dataset

# %% [markdown]
# Create your team and name it **Artin_FC**. Add your 11 favorite players to the team, including yourself. The dictionary for each player must contain the following keys:

# %%
Haaland = {"name":"Haaland",
         "position":"Right Winger",
         "goals":53,
         "assists":7,
         "accuracy":87,
         "stamina":95
}

# %%
# TODO

Artin_FC = [
{"name": "Artin", "position":"LW", "goals": 100, "assists": 42, "accuracy": 97, "stamina": 99},
{"name": "Messi", "position" :"CF", "goals": 91, "assists": 48, "accuracy": 99, "stamina": 84},
{"name": "Jahanbakhsh", "position":"RW", "goals": 23, "assists": 14, "accuracy": 81, "stamina": 78},
{'name': "Maradona", "position" :"CAM", "goals": 25, "assists": 21, "accuracy": 93, "stamina": 75},
{'name': "Zidane", "position" :"CM", "goals": 7, "assists": 9, "accuracy": 96, "stamina": 88},
{'name': "Iniesta", "position" :"CDM", "goals": 2, "assists": 6, "accuracy": 89, "stamina": 92},
{'name': "Marcelo", "position" :"LB", "goals": 2, "assists": 10, "accuracy": 94, "stamina": 87},
{'name': "Pique", "position" :"CB", "goals": 2, "assists": 1, "accuracy": 79, "stamina": 80},
{'name': "Maldini", "position" :"CB", "goals": 1, "assists": 0, "accuracy": 72, "stamina": 95},
{'name': "Dani Alves", "position" :"RB", "goals": 4, "assists": 5, "accuracy": 92, "stamina": 91},
{"name": "Beirandvand", "position" :"GK", "goals": 0, "assists": 0, "accuracy": 68, "stamina": 45}
]

print(Artin_FC)
# Out:
# [{'name': 'Artin', 'position': 'LW', 'goals': 100, 'assists': 42, 'accuracy': 97, 'stamina': 99}, {'name': 'Messi', 'position': 'CF', 'goals': 91, 'assists': 48, 'accuracy': 99, 'stamina': 84}, {'name': 'Jahanbakhsh', 'position': 'RW', 'goals': 23, 'assists': 14, 'accuracy': 81, 'stamina': 78}, {'name': 'Maradona', 'position': 'CAM', 'goals': 25, 'assists': 21, 'accuracy': 93, 'stamina': 75}, {'name': 'Zidane', 'position': 'CM', 'goals': 7, 'assists': 9, 'accuracy': 96, 'stamina': 88}, {'name': 'Iniesta', 'position': 'CDM', 'goals': 2, 'assists': 6, 'accuracy': 89, 'stamina': 92}, {'name': 'Marcelo', 'position': 'LB', 'goals': 2, 'assists': 10, 'accuracy': 94, 'stamina': 87}, {'name': 'Pique', 'position': 'CB', 'goals': 2, 'assists': 1, 'accuracy': 79, 'stamina': 80}, {'name': 'Maldini', 'position': 'CB', 'goals': 1, 'assists': 0, 'accuracy': 72, 'stamina': 95}, {'name': 'Dani Alves', 'position': 'RB', 'goals': 4, 'assists': 5, 'accuracy': 92, 'stamina': 91}, {'name': 'Beirandvand', 
# ...

# %% [markdown]
# I have created the followin sample soccer dataset. Feel free to use your own dataset instead.

# %%
#Artin_FC = [
    {"name":"Alex","position":"Goalkeeper","goals":0,"assists":1,"accuracy":82,"stamina":91},
    {"name":"Ben","position":"Defender","goals":2,"assists":3,"accuracy":79,"stamina":88},
    {"name":"Carlos","position":"Defender","goals":1,"assists":2,"accuracy":81,"stamina":86},
    {"name":"Daniel","position":"Defender","goals":0,"assists":4,"accuracy":80,"stamina":90},
    {"name":"Ethan","position":"Defender","goals":1,"assists":1,"accuracy":84,"stamina":87},
    {"name":"Finn","position":"Midfielder","goals":5,"assists":7,"accuracy":88,"stamina":92},
    {"name":"George","position":"Midfielder","goals":4,"assists":5,"accuracy":86,"stamina":89},
    {"name":"Henry","position":"Midfielder","goals":6,"assists":8,"accuracy":90,"stamina":93},
    {"name":"Isaac","position":"Forward","goals":12,"assists":6,"accuracy":94,"stamina":90},
    {"name":"Jack","position":"Forward","goals":10,"assists":5,"accuracy":91,"stamina":88},
    {"name":"Kevin","position":"Forward","goals":14,"assists":4,"accuracy":95,"stamina":91},
]

#print(Artin_FC)

# %% [markdown]
# ## Part 3 – Accessing Data

# %%
print(Artin_FC[0])
# Out:
# {'name': 'Artin', 'position': 'LW', 'goals': 100, 'assists': 42, 'accuracy': 97, 'stamina': 99}

# %%
print(Artin_FC[0]["name"])
# Out:
# Artin

# %%
print(Artin_FC[5]["position"])
# Out:
# CM

# %%
print(Artin_FC[10]["goals"])
# Out:
# 4

# %% [markdown]
# ### ✏️ Exercises
# 1. Print the goalkeeper's name.

# %%
print(Artin_FC[10]["name"])
# Out:
# Beirandvand

# %% [markdown]
# 2. Print the first forward's goals.

# %%
print(Artin_FC[0]["goals"])
# Out:
# 100

# %% [markdown]
# 3. Print Pique's stamina.

# %%
print(Artin_FC[7]["stamina"])
# Out:
# 80

# %% [markdown]
# 4. Print Maradona's accuracy.

# %%
print(Artin_FC[3]["accuracy"])
# Out:
# 93

# %% [markdown]
# ## Part 3 – Updating Data

# %%
Artin_FC[0]["goals"] += 1
Artin_FC[1]["accuracy"] += 2
Artin_FC[8]["stamina"] -= 3

# %%
print(Artin_FC[0])
# Out:
# {'name': 'Artin', 'position': 'LW', 'goals': 101, 'assists': 42, 'accuracy': 97, 'stamina': 99}

# %%
print(Artin_FC[1])
# Out:
# {'name': 'Messi', 'position': 'CF', 'goals': 91, 'assists': 48, 'accuracy': 101, 'stamina': 84}

# %%
print(Artin_FC[8])
# Out:
# {'name': 'Maldini', 'position': 'CB', 'goals': 1, 'assists': 0, 'accuracy': 72, 'stamina': 92}

# %% [markdown]
# Why didn't we create a new dictionary?

# %% [markdown]
# ## Part 4 – Add New Features

# %% [markdown]
# Add two new features to each player dictionary:
# - spead
# - passing

# %%
Artin_FC[0]["speed"] = 99
Artin_FC[0]["passing"] = 89


Artin_FC[0]
# Out:
# {'name': 'Artin',
#  'position': 'LW',
#  'goals': 101,
#  'assists': 42,
#  'accuracy': 97,
#  'stamina': 99,
#  'speed': 99,
#  'passing': 89}

# %% [markdown]
# What other information would an AI coach want?
#
# Possible answers:
#
# - height
# - weight
# - preferred foot
# - yellow cards
# - red cards
# - matches played
# - minutes played
#
# Add "speed" and "passing" fields to each player dictionary in your dataset.

# %%
Artin_FC = [
{"name": "Artin", "position":"LW", "goals": 100, "assists": 42, "accuracy": 97, "stamina": 99, "speed": 99, "passing": 89},
{"name": "Messi", "position" :"CF", "goals": 91, "assists": 48, "accuracy": 99, "stamina": 84, "speed": 91, "passing": 99},
{"name": "Jahanbakhsh", "position":"RW", "goals": 23, "assists": 14, "accuracy": 81, "stamina": 78, "speed": 78, "passing": 83},
{'name': "Maradona", "position" :"CAM", "goals": 25, "assists": 21, "accuracy": 93, "stamina": 75, "speed": 85, "passing": 94},
{'name': "Zidane", "position" :"CM", "goals": 7, "assists": 9, "accuracy": 96, "stamina": 88, "speed": 77, "passing": 97},
{'name': "Iniesta", "position" :"CDM", "goals": 2, "assists": 6, "accuracy": 89, "stamina": 92, "speed": 78, "passing": 97},
{'name': "Marcelo", "position" :"LB", "goals": 2, "assists": 10, "accuracy": 94, "stamina": 87, "speed": 83, "passing": 92},
{'name': "Pique", "position" :"CB", "goals": 2, "assists": 1, "accuracy": 79, "stamina": 80, "speed": 71, "passing": 99},
{'name': "Maldini", "position" :"CB", "goals": 1, "assists": 0, "accuracy": 72, "stamina": 95, "speed": 91, "passing": 89},
{'name': "Dani Alves", "position" :"RB", "goals": 4, "assists": 5, "accuracy": 92, "stamina": 91, "speed": 84, "passing": 90},
{"name": "Beirandvand", "position" :"GK", "goals": 0, "assists": 0, "accuracy": 68, "stamina": 63, "speed": 87, "passing": 75}
]

print(Artin_FC)
# Out:
# [{'name': 'Artin', 'position': 'LW', 'goals': 100, 'assists': 42, 'accuracy': 97, 'stamina': 99, 'speed': 99, 'passing': 89}, {'name': 'Messi', 'position': 'CF', 'goals': 91, 'assists': 48, 'accuracy': 99, 'stamina': 84, 'speed': 91, 'passing': 99}, {'name': 'Jahanbakhsh', 'position': 'RW', 'goals': 23, 'assists': 14, 'accuracy': 81, 'stamina': 78, 'speed': 78, 'passing': 83}, {'name': 'Maradona', 'position': 'CAM', 'goals': 25, 'assists': 21, 'accuracy': 93, 'stamina': 75, 'speed': 85, 'passing': 94}, {'name': 'Zidane', 'position': 'CM', 'goals': 7, 'assists': 9, 'accuracy': 96, 'stamina': 88, 'speed': 77, 'passing': 97}, {'name': 'Iniesta', 'position': 'CDM', 'goals': 2, 'assists': 6, 'accuracy': 89, 'stamina': 92, 'speed': 78, 'passing': 97}, {'name': 'Marcelo', 'position': 'LB', 'goals': 2, 'assists': 10, 'accuracy': 94, 'stamina': 87, 'speed': 83, 'passing': 92}, {'name': 'Pique', 'position': 'CB', 'goals': 2, 'assists': 1, 'accuracy': 79, 'stamina': 80, 'speed': 71, 'passing': 
# ...

# %% [markdown]
# Before software engineers write code, they design the data. And you created your first soccer dataset (Artin_FC). **Congratulations!**

# %% [markdown]
# ## Part 5 – Apply Arithmetic on Your Dataset

# %%
player = Artin_FC[8]

total_contribution = player["goals"] + player["assists"]
overall_movement = (player["speed"] + player["stamina"]) / 2

# %%
print("Player:", player["name"])
# Out:
# Player: Maldini

# %%
print("Total Contribution:", total_contribution)
# Out:
# Total Contribution: 1

# %%
print("Overall movement:", overall_movement)
# Out:
# Overall movement: 93.0

# %% [markdown]
# ## Part 6 – Develop Your First Functions

# %%
def total_contribution(player):
    total=player["goals"] + player["assists"]
    return total
# Out:
# 0

# %%
total_contribution(Artin_FC[10])

# %%
total_contribution(Artin_FC[9])

# %%
def player_summary(player):
    print("⚽ Final Player Report ⚽")
    print("="*30)
    print("Player:", player["name"])
    print("Position:", player["position"])
    print("Goals:", player["goals"])
    print("Assists:", player["assists"])
    print("Contribution:", total_contribution(player))
    print("="*30)

#player_summary(team[10])

# %%
player_summary(Artin_FC[2])
# Out:
# ⚽ Final Player Report ⚽
# ...
# Player: Jahanbakhsh
# Position: RW
# Goals: 23
# Assists: 14
# Contribution: 37
# ...

# %%
player_summary(Artin_FC[3])
# Out:
# ⚽ Final Player Report ⚽
# ...
# Player: Maradona
# Position: CAM
# Goals: 25
# Assists: 21
# Contribution: 46
# ...

# %% [markdown]
# ## 🧠 Coach Thinking Questions
# - Which player would you choose as captain?

# %% [markdown]
# Artin by far no questions needed why.

# %% [markdown]
# - Which player has the best balance of goals and assists?

# %% [markdown]
# Seyed Artin Sharifi Asl.

# %% [markdown]
# - What new information would help an AI coach make better decisions?

# %% [markdown]
# Adding more info like minutes played so we could find how many minutes it takes for a player to get a goal, assist, or goal contribution or something else that you could use the "minutes played" to find.

# %% [markdown]
# # ⭐ Mission Challenge
#
# Create a function called `ai_report(player)` that prints:
#
# - Name
# - Position
# - Goals
# - Assists
# - Accuracy
# - Stamina
# - Total Contribution
#
# Then call it for three different players.

# %%
def ai_report(player):
    print("⚽ Final Player Report ⚽")
    print("="*30)
    print("Player:", player["name"])
    print("Position:", player["position"])
    print("Goals:", player["goals"])
    print("Assists:", player["assists"])
    print("Contribution:", total_contribution(player))
    print("Accuracy:", player["accuracy"])
    print("Stamina:", player["stamina"])
    print("="*30)

# %% [markdown]
# # 🚀 Mission Complete
#
# Congratulations!
#
# Today you learned how to navigate and manipulate a real soccer dataset.
#
# Next mission: **Using loops to automatically analyze every player on the team.**
